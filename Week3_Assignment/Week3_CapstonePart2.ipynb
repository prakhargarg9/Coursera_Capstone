# %% [markdown]
# # This notebook is created to do part 2 of Week 3 assignment of Applied Data Science Capstone

# %% [markdown]
# ### We will find out the latitude and longitude cordinates of each neighborhood so that we could utilize the Foursquare API

# %% [markdown]
# #### Step 1 - Lets load the csv file <b>Toronto_Data.csv</b>, we created in Part 1 into a dataframe.

# %%
import pandas as pd

# Toronto_data = pd.read_csv("Toronto_Data.csv",index_col = 0)
Toronto_data = pd.read_csv("Toronto_Data.csv")#This csv file is present in the local folder
Toronto_data.sort_values(['Postal Code'], inplace=True,ignore_index = True)
# Toronto_data.reset_index(drop=True)
print(Toronto_data.shape)
Toronto_data
# Out:
# (103, 3)
#     Postal Code      Borough  \
# 0           M1B  Scarborough
# 1           M1C  Scarborough
# 2           M1E  Scarborough
# 3           M1G  Scarborough
# 4           M1H  Scarborough
# ..          ...          ...
# 98          M9N         York
# 99          M9P    Etobicoke
# 100         M9R    Etobicoke
# 101         M9V    Etobicoke
# 102         M9W    Etobicoke
#
#                                           Neighborhood
# 0                                       Malvern, Rouge
# 1               Rouge Hill, Port Union, Highland Creek
# 2                    Guildwood, Morningside, West Hill
# 3                                               Woburn
# 4                                            Cedarbrae
# ..                                                 ...
# 98                                              Weston
# 99                                           Westmount
# 100  Kingsview Village, St. Phillips, Martin Grove ...
# ...

# %% [markdown]
# #### Step 2 - Use the geocoder package to find the geographical coordinates of a given postal code

# %%
# # # !pip install geocoder
# import geocoder # import geocoder

# # initialize your variable to None
# lat_lng_coords = None
# # loop until you get the coordinates
# for i in Range(103):
#   print("A") 
#   g = geocoder.google('{}, Toronto, Ontario'.format(Toronto_data["Postal Code"])
#   lat_lng_coords = g.latlng

# latitude = lat_lng_coords[0]
# longitude = lat_lng_coords[1]

# print(latitude)
# print(longitude)
# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
# !pip install geopy
# from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
# latitude = []
# longitude = []

# for postal_code in Toronto_data["Postal Code"]:
#     print(postal_code)
#     address = '{}, Toronto, Ontario'.format(postal_code)

#     geolocator = Nominatim(user_agent="toronto_explorer")
#     location = None
#     while(location is None):
#         print("A")
#         location = geolocator.geocode(address)    
#     latitude.append(location.latitude)
#     longitude.append(location.longitude)
    
# print(latitude)
# print(longitude)
# import geocoder


# def get_geocoder(postal_code_from_df):
#      # initialize your variable to None
#      lat_lng_coords = None
#      # loop until you get the coordinates
#      while(lat_lng_coords is None):
#        g = geocoder.google('{}, Toronto, Ontario'.format(postal_code_from_df))
#        lat_lng_coords = g.latlng
#      latitude = lat_lng_coords[0]
#      longitude = lat_lng_coords[1]
#      return latitude,longitude



# for i in range(0,len(Toronto_data)):
#     Toronto_data['Latitude'][i],Toronto_data['Longitude'][i]=get_geocoder(Toronto_data.iloc[i]['Postal Code'])

# %% [markdown]
# ##### <b>Reading the given file for longitude and latitude</b>

# %%
# !wget -q -O Geospatial_Coordinates.csv http://cocl.us/Geospatial_data
print('Data downloaded!')
# Out:
# Data downloaded!

# %%
df = pd.read_csv('Geospatial_Coordinates.csv')
df.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
Toronto_data['Latitude'] = df['Latitude']
Toronto_data['Longitude'] = df['Longitude']
Toronto_data
# Out:
#     Postal Code      Borough  \
# 0           M1B  Scarborough
# 1           M1C  Scarborough
# 2           M1E  Scarborough
# 3           M1G  Scarborough
# 4           M1H  Scarborough
# ..          ...          ...
# 98          M9N         York
# 99          M9P    Etobicoke
# 100         M9R    Etobicoke
# 101         M9V    Etobicoke
# 102         M9W    Etobicoke
#
#                                           Neighborhood   Latitude  Longitude
# 0                                       Malvern, Rouge  43.806686 -79.194353
# 1               Rouge Hill, Port Union, Highland Creek  43.784535 -79.160497
# 2                    Guildwood, Morningside, West Hill  43.763573 -79.188711
# 3                                               Woburn  43.770992 -79.216917
# 4                                            Cedarbrae  43.773136 -79.239476
# ..                                                 ...        ...        ...
# ...

# %%
Toronto_data.to_csv('Toronto_Final_DataFrame.csv',index=False)
